# %%
# https://www.tensorflow.org/tutorials/load_data/csv#mixed_data_types


import pandas as pd
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
from tensorflow import keras
from keras import layers


titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
titanic.head()
# Out:
# 2023-08-27 11:42:00.178901: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-27 11:42:00.207151: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-27 11:42:00.208101: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-27 11:42:00.777960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
titanic_features = titanic.copy()
titanic_labels = titanic_features.pop('survived')

# %%
inputs = {}

for name, column in titanic_features.items():
  dtype = column.dtype
  if dtype == object:
    dtype = tf.string
  else:
    dtype = tf.float32

  inputs[name] = tf.keras.Input(shape=(1,), name=name, dtype=dtype)

inputs
# Out:
# {'sex': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'sex')>,
#  'age': <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'age')>,
#  'n_siblings_spouses': <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'n_siblings_spouses')>,
#  'parch': <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'parch')>,
#  'fare': <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'fare')>,
#  'class': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'class')>,
#  'deck': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'deck')>,
#  'embark_town': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'embark_town')>,
#  'alone': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'alone')>}

# %%
numeric_inputs = {name:input for name,input in inputs.items()
                  if input.dtype==tf.float32}

x = layers.Concatenate()(list(numeric_inputs.values()))
norm = layers.Normalization()
norm.adapt(np.array(titanic[numeric_inputs.keys()]))
all_numeric_inputs = norm(x)

all_numeric_inputs

preprocessed_inputs = [all_numeric_inputs]
# Out:
# 2023-08-27 11:42:14.582192: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
for name, input in inputs.items():
  if input.dtype == tf.float32:
    continue

  lookup = layers.StringLookup(vocabulary=np.unique(titanic_features[name]))
  one_hot = layers.CategoryEncoding(num_tokens=lookup.vocabulary_size())

  x = lookup(input)
  x = one_hot(x)
  preprocessed_inputs.append(x)

# %%
preprocessed_inputs_cat = layers.Concatenate()(preprocessed_inputs)

titanic_preprocessing = tf.keras.Model(inputs, preprocessed_inputs_cat)
# tf.keras.utils.plot_model(model = titanic_preprocessing , rankdir="LR", dpi=72, show_shapes=True)

# %%
titanic_features_dict = {name: np.array(value) 
                         for name, value in titanic_features.items()}

features_dict = {name:values[:1] for name, values in titanic_features_dict.items()}
# titanic_preprocessing(features_dict)    ## this is just to show the results of the preprocessing

# %%
def titanic_model(preprocessing_head, inputs):
  body = tf.keras.Sequential([
    layers.Dense(64),
    layers.Dense(1)
  ])

  preprocessed_inputs = preprocessing_head(inputs)
  result = body(preprocessed_inputs)
  model = tf.keras.Model(inputs, result)

  model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])
  return model

titanic_model = titanic_model(titanic_preprocessing, inputs)
titanic_model.fit(x=titanic_features_dict, y=titanic_labels, epochs=50)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6964
# Epoch 2/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5717
# Epoch 3/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5124
# Epoch 4/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4761
# Epoch 5/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4555
# Epoch 6/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4421
# Epoch 7/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4339
# Epoch 8/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4276
# Epoch 9/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4241
# Epoch 10/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4223
# Epoch 11/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4217
# Epoch 12/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4221
# Epoch 13/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4200
# Epoch 14/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4199
# Epoch 15/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4205
# Epoch 16/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4194
# Epoch 17/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4200
# Epoch 18/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4182
# Epoch 19/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4190
# Epoch 20/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4183
# Epoch 21/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4193
# Epoch 22/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4190
# Epoch 23/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4187
# Epoch 24/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4186
# Epoch 25/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4184
# Epoch 26/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4181
# Epoch 27/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4177
# Epoch 28/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4179
# Epoch 29/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4188
# Epoch 30/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4187
# Epoch 31/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4180
# Epoch 32/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4187
# Epoch 33/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4184
# Epoch 34/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4178
# Epoch 35/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4216
# Epoch 36/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4170
# Epoch 37/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4231
# Epoch 38/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4207
# Epoch 39/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4169
# Epoch 40/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4193
# Epoch 41/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4188
# Epoch 42/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4185
# Epoch 43/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4175
# Epoch 44/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4191
# Epoch 45/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4181
# Epoch 46/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4174
# Epoch 47/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4178
# Epoch 48/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4193
# Epoch 49/50
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4171
# Epoch 50/50
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4193
